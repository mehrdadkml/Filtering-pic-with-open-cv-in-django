# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /home/mehrdad/.local/lib/python3.9/site-packages (3.7.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/mehrdad/.local/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /home/mehrdad/.local/lib/python3.9/site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/mehrdad/.local/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/mehrdad/.local/lib/python3.9/site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: numpy>=1.20 in /home/mehrdad/.local/lib/python3.9/site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: importlib-resources>=3.2.0; python_version < "3.10" in /home/mehrdad/.local/lib/python3.9/site-packages (from matplotlib) (5.12.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/mehrdad/.local/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /home/mehrdad/.local/lib/python3.9/site-packages (from matplotlib) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/mehrdad/.local/lib/python3.9/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /home/mehrdad/.local/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib) (1.14.0)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in /home/mehrdad/.local/lib/python3.9/site-packages (from importlib-resources>=3.2.0; python_version < "3.10"->matplotlib) (3.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -U Pillow
# Out:
# Requirement already up-to-date: Pillow in /home/mehrdad/.local/lib/python3.9/site-packages (9.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
img=cv2.imread("12.jpg")
img
# Out:
# array([[[  1,   6,  39],
#         [ 51,  57,  92],
#         [ 32,  41,  78],
#         ...,
#         [ 67,  70, 151],
#         [ 66,  71, 150],
#         [ 71,  76, 155]],
#
#        [[  2,   7,  40],
#         [ 48,  55,  88],
#         [ 33,  42,  79],
#         ...,
#         [ 64,  68, 147],
#         [ 52,  56, 135],
#         [ 45,  51, 128]],
#
#        [[  0,   1,  32],
#         [ 46,  54,  84],
#         [ 38,  48,  82],
#         ...,
#         [ 75,  79, 158],
#         [ 60,  64, 142],
#         [ 50,  55, 130]],
#
#        ...,
#
#        [[  0,   1,   5],
#         [  4,   5,   9],
#         [  6,   7,  11],
#         ...,
#         [  8,   9,  19],
#         [  9,  10,  20],
#         [  9,  10,  20]],
#
#        [[  0,   0,   4],
#         [  3,   4,   8],
#         [  4,   5,   9],
#         ...,
#         [  7,   6,  15],
#         [  8,   7,  17],
#         [  7,   6,  16]],
#
#        [[  0,   0,   3],
#         [  0,   1,   5],
#         [  1,   2,   6],
#         ...,
#         [  4,   3,  12],
#         [  4,   3,  13],
#         [  4,   3,  13]]], dtype=uint8)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (540, 960, 3)

# %%
plt.imshow(img)

# %%
normal=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(normal)

# %%
def get_image(image,cmap=None):
    plt.axis('off')
    plt.imshow(image, cmap=cmap)
    plt.show()

# %%
get_image(normal)

# %%
hsv=cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
get_image(hsv)

# %%
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
get_image(gray,cmap="gray")

# %%
width,height=normal.shape[:2]
# print(width)
# print(height)
if width>500:
    k=(50,50)
elif width>200 and width <=500:
    k=(25,25)
else:
    k=(10,10)

blur=cv2.blur(normal, k)
get_image(blur)
print(k)
# Out:
# (50, 50)

# %%
v , binary=cv2.threshold(gray,100,255,cv2.THRESH_BINARY)
get_image(binary,cmap="gray")

# %%
invert=cv2.bitwise_not(binary)
get_image(invert,cmap="gray")
